# %% [markdown]
# # Co-add Image

# %%
from reproject import reproject_interp
from reproject.mosaicking import reproject_and_coadd
from reproject.mosaicking import find_optimal_celestial_wcs
from astropy.io import fits
from astropy.table import Table
import sys, os
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.wcs import WCS
from astropy.io.fits import Header
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.nddata import Cutout2D
from coadd import *

# %%
-2.5 * np.log10(1e-3*1e-3/3631)
# Out:
# 23.90006562228223

# %%
flist = [
    '/Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/EP260105a/LCO/elp1m006-fa11-20260118-0273-e91.fits.fz',
    '/Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/EP260105a/LCO/elp1m006-fa11-20260118-0274-e91.fits.fz',
    '/Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/EP260105a/LCO/elp1m006-fa11-20260118-0275-e91.fits.fz'
]

save_dir = '/Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/EP260105a/LCO'
prefix = 'LCO_stack_260120.fits'

# %%
coadd(flist, size=None, save_dir=save_dir, prefix=prefix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 coadd(flist, size=None, save_dir=save_dir, prefix=prefix)
#
# NameError: name 'flist' is not defined

# %%
event_name = 'EP260116a'
root = f"/Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/{event_name}/LCO"
save_dir = f"/Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/{event_name}/LCO/stack"
coadd_lco(root, save_dir, dt=1)
# Out:
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   149.070847 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -31.272819 from OBSGEO-[XYZ].
# Set OBSGEO-H to     1126.993 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    20.810039 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -32.347341 from OBSGEO-[XYZ].
# Set OBSGEO-H to     1756.994 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# [OK] gp: 6 images → /Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/EP260116a/LCO/stack/coj2m002_20260121T135134.871_gp.fits
# [OK] rp: 6 images → /Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/EP260116a/LCO/stack/coj2m002_20260121T135134.874_rp.fits
# [OK] ip: 6 images → /Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/EP260116a/LCO/stack/coj2m002_20260121T135134.876_ip.fits
# [OK] zs: 6 images → /Volumes/T7/Shared_Files/EP/Results/Follow_up/optical_data/EP260116a/LCO/stack/coj2m002_20260121T135134.851_zs.fits
# ...
