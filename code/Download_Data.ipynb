# %% [markdown]
# # Download Data

# %%
import warnings
warnings.filterwarnings("ignore")
from astropy.table import Table, Column, vstack
from astropy.coordinates import SkyCoord
from astropy.time import Time
import astropy.units as u
import numpy as np
import pandas as pd
import subprocess
import sys, os, json
from ipyaladin import Aladin
from astroquery.ned import Ned
from astroquery.sdss import SDSS
from astropy import coordinates as coords
from utils import *
from catalog import *
from photometry import *
# sys.path.append('/Volumes/T7/Shared_Files/EP/Projects')
# from host_solver import HostGalaxyFinder
# from region import *
check_source_dirs()

# %%
get_tnot_data()
# Out:
# Found 17 remote files.
# [SKIP] File already exists: /home/liangrd/Follow_up/optical_data/EP251222a/TNOT/stack_EP251222a_rp_wcs.fits
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251212/stack_WXTJ043559-012325_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/WXTJ043559-012325/TNOT
# [SKIP] File already exists: /home/liangrd/Follow_up/optical_data/EP260131a/TNOT/stack_EP260131a_rp_wcs.fits
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251219/stack_EPJ0619.5+0606_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/EPJ0619.5+0606/TNOT
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251213/stack_WXT_J001838+115903_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/WXT/TNOT
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251208/stack_RXSJ052540.6+425139_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/RXSJ052540.6+425139/TNOT
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251208/stack_WXTJ031644+08d316_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/WXTJ031644+08d316/TNOT
# [SKIP] File already exists: /home/liangrd/Follow_up/optical_data/EP251222a/TNOT/stack_EP251222a_rp_wcs.fits
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251209/stack_WXTJ032216+233553_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/WXTJ032216+233553/TNOT
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251209/stack_WXTJ110746+454221_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/WXTJ110746+454221/TNOT
# [SKIP] File already exists: /home/liangrd/Follow_up/optical_data/EP251221a/TNOT/stack_EP251221a_rp_wcs.fits
# [Downloading] stack_EP260209a_rp_wcs.fits →
# /home/liangrd/Follow_up/optical_data/EP260209a/TNOT/stack_EP260209a_rp_wcs.fits
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251211/stack_WXTJ2_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/WXTJ2/TNOT
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251213_Li/stack_WXT_J001838+115903_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/WXT/TNOT
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20260109/stack_WXT_J030902+581637_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/WXT/TNOT
# [SKIP] File already exists: /home/liangrd/Follow_up/optical_data/EP251222a/TNOT/stack_EP251222a_rp_wcs.fits
# [SKIP] Local directory does not exist for target '/home/tnot/EP/20251214/stack_EP20251214a_rp_wcs.fits':
# /home/liangrd/Follow_up/optical_data/EP20251214a/TNOT
# {'EP251222a': ['/home/liangrd/Follow_up/optical_data/EP251222a/TNOT/stack_EP251222a_rp_wcs.fits',
#   '/home/liangrd/Follow_up/optical_data/EP251222a/TNOT/stack_EP251222a_rp_wcs.fits',
#   '/home/liangrd/Follow_up/optical_data/EP251222a/TNOT/stack_EP251222a_rp_wcs.fits'],
#  'EP260131a': ['/home/liangrd/Follow_up/optical_data/EP260131a/TNOT/stack_EP260131a_rp_wcs.fits'],
#  'EP251221a': ['/home/liangrd/Follow_up/optical_data/EP251221a/TNOT/stack_EP251221a_rp_wcs.fits'],
#  'EP260209a': ['/home/liangrd/Follow_up/optical_data/EP260209a/TNOT/stack_EP260209a_rp_wcs.fits']}

# %%
get_sitian_data()
# Out:
# 🔍 Querying remote Sitian files...
# 📦 Found 30 files on server
# ⏭️ Skip existing: 2025-12-27_EP251222a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2025-12-28_EP251222a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2025-12-29_EP251222a_g_com_5.wcs.fits
# ⏭️ Skip existing: 2025-12-30_EP251229a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2025-12-31_EP251229a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-03_EP260101a_g_com_3.wcs.fits
# ⏭️ Skip existing: 2026-01-05_EP260104a_g_com_9.wcs.fits
# ⏭️ Skip existing: 2026-01-05_EP260105a_g_com_1.wcs.fits
# ⏭️ Skip existing: 2026-01-06_EP260104a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-06_EP260105a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-07_EP260104a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-08_EP260101a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-10_EP260105b_g_com_3.wcs.fits
# ⏭️ Skip existing: 2026-01-11_EP260110a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-12_EP260104a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-12_EP260105a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-12_EP260110a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-13_EP260101a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-15_EP260101a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-16_EP251221a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-17_EP251221a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-20_EP260110a_g_com_9.wcs.fits
# ⏭️ Skip existing: 2026-01-21_EP251229a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-21_EP260101a_g_com_9.wcs.fits
# ⏭️ Skip existing: 2026-01-22_EP251229a_g_com_9.wcs.fits
# ⏭️ Skip existing: 2026-01-22_EP260101a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-22_EP260105a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-22_EP260110a_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-23_EP260105b_g_com_10.wcs.fits
# ⏭️ Skip existing: 2026-01-23_EP260116a_g_com_10.wcs.fits
# ✅ Sitian data download finished.
