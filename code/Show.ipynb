# %%
import warnings
warnings.filterwarnings('ignore')
from astropy.io import fits
import astropy.units as u
import matplotlib.pyplot as plt
from utils import fits_plot, show_shift
ps_band = 'g'

fdir = '/home/liangrd/optical_data/EP260530a/sitian/2026-06-01_EP260530a_g_com_10.wcs.fits'

fig = fits_plot(fdir,size=30,show_ps=True,ps_filter=ps_band,radius=2.0)
# Out:
# ---------------------------------------------------------------------------
# NoOverlapError                            Traceback (most recent call last)
# Cell In[1], line 11
#       7 ps_band = 'g'
#       9 fdir = '/home/liangrd/optical_data/EP260530a/sitian/2026-06-01_EP260530a_g_com_10.wcs.fits'
# ---> 11 fig = fits_plot(fdir,size=30,show_ps=True,ps_filter=ps_band,radius=2.0)
#
# File ~/Follow_up/code/utils.py:635, in fits_plot(fdir, radius, source_dir, size, contrast, show_ps, ps_filter, ra, dec, **imshow_kwargs)
#     631         coord = SkyCoord(ra=float(row.iloc[0]['RA'])*u.deg,
#     632                      dec=float(row.iloc[0]['Dec'])*u.deg, frame='fk5')
#     634 # ---------- 3. Main cutout ----------
# --> 635 cutout = Cutout2D(data, coord, size, wcs=wcs)
#     636 zscale = ZScaleInterval(contrast=contrast)
#     637 vmin, vmax = zscale.get_limits(cutout.data)
#
# File ~/epenv/lib/python3.12/site-packages/astropy/nddata/utils.py:599, in Cutout2D.__init__(self, data, position, size, wcs, mode, fill_value, copy)
#     595 # reverse position because extract_array and overlap_slices
#     596 # use (y, x), but keep the input position
#     597 pos_yx = position[::-1]
# --> 599 cutout_data, input_position_cutout = extract_array(
#     600     data,
#     601     tuple(shape),
#     602     pos_yx,
#     603     mode=mode,
#     604     fill_value=fill_value,
#     605     return_position=True,
#     606 )
#     607 if copy:
#     608     cutout_data = np.copy(cutout_data)
#
# File ~/epenv/lib/python3.12/site-packages/astropy/nddata/utils.py:236, in extract_array(array_large, shape, position, mode, fill_value, return_position)
#     233 if mode not in ["partial", "trim", "strict"]:
#     234     raise ValueError("Valid modes are 'partial', 'trim', and 'strict'.")
# --> 236 large_slices, small_slices = overlap_slices(
#     237     array_large.shape, shape, position, mode=mode
#     238 )
#     239 extracted_array = array_large[large_slices]
#     240 if return_position:
#
# File ~/epenv/lib/python3.12/site-packages/astropy/nddata/utils.py:122, in overlap_slices(large_array_shape, small_array_shape, position, mode)
#     120 for e_min, large_shape in zip(indices_min, large_array_shape):
#     121     if e_min >= large_shape:
# --> 122         raise NoOverlapError("Arrays do not overlap.")
#     124 if mode == "strict":
#     125     for e_min in indices_min:
#
# NoOverlapError: Arrays do not overlap.

# %%
show_shift(root='/home/liangrd/Follow_up/optical_data',save_dir='/home/liangrd/Follow_up/results')
# Out:
# [ERROR] /home/liangrd/Follow_up/optical_data/EP251229a/sitian/2025-12-30_EP251229a_g_com_10.wcs.fits: buffer is too
# small for requested array
# [ERROR] /home/liangrd/Follow_up/optical_data/EP251229a/sitian/2025-12-31_EP251229a_g_com_10.wcs.fits: buffer is too
# small for requested array

# %%
hdu = fits.open(fdir)
header = hdu[0].header

header
# Out:
# SIMPLE  =                    T / This is a FITS file
# BITPIX  =                  -32 /
# NAXIS   =                    2 /
# NAXIS1  =                11477 / NUMBER OF ELEMENTS ALONG THIS AXIS
# NAXIS2  =                 9087 / NUMBER OF ELEMENTS ALONG THIS AXIS
# EXTEND  =                    T / This file may contain FITS extensions
# EQUINOX =        2000.00000000 / Mean equinox
# MJD-OBS =       61192.55005787 / Modified Julian date at start
# RADESYS = 'ICRS    '           / Astrometric system
# CTYPE1  = 'RA---TAN'           / WCS projection type for this axis
# CUNIT1  = 'deg     '           / Axis unit
# CRVAL1  =   1.857986974698E+02 / World coordinate on this axis
# CRPIX1  =   5.739000000000E+03 / Reference pixel on this axis
# CD1_1   =  -1.032490981743E-04 / Linear projection matrix
# CD1_2   =   0.000000000000E+00 / Linear projection matrix
# CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis
# CUNIT2  = 'deg     '           / Axis unit
# CRVAL2  =   8.925090311491E+00 / World coordinate on this axis
# CRPIX2  =   4.544000000000E+03 / Reference pixel on this axis
# CD2_1   =   0.000000000000E+00 / Linear projection matrix
# CD2_2   =   1.032490981743E-04 / Linear projection matrix
# EXPTIME =   1.800000000000E+03 / Maximum equivalent exposure time (s)
# GAIN    =   3.183098861838E+02 / Maximum equivalent gain (e-/ADU)
# SATURATE=   6.563206465863E+04 / Saturation Level (ADU)
# COMMENT
# SOFTNAME= 'SWarp   '           / The software that processed those data
# SOFTVERS= '2.41.5  '           / Version of the software
# SOFTDATE= '2021-01-27'         / Release date of the software
# SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software
# SOFTINST= 'IAP  http://www.iap.fr' / Institute
# COMMENT
# AUTHOR  = 'unknown '           / Who ran the software
# ORIGIN  = 'x-opstep'           / Where it was done
# DATE    = '2026-06-02T03:34:39' / When it was started (GMT)
# COMBINET= 'MEDIAN  '           / COMBINE_TYPE config parameter for SWarp
# COMMENT
# COMMENT  Propagated FITS keywords
# OBJECT  = 'EP260530a'          / Name of the object of interest
# COMMENT
# COMMENT  Axis-dependent config parameters
# RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter
# CENTERT1= 'ALL     '           / CENTER_TYPE config parameter
# PSCALET1= 'MEDIAN  '           / PIXELSCALE_TYPE config parameter
# RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter
# CENTERT2= 'ALL     '           / CENTER_TYPE config parameter
# PSCALET2= 'MEDIAN  '           / PIXELSCALE_TYPE config parameter

# %%
header['OBJECT']
# Out:
# 'EP260131a'

# %%
import time
import pandas as pd

t = pd.Timestamp('2026-01-25T21:03:16.395375+00:00')
t.strftime("%Y-%m-%dT%H:%M:%S.%f")
# Out:
# '2026-01-25T21:03:16.395375'
