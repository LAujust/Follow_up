# %%
import warnings
warnings.filterwarnings('ignore')
from astropy.io import fits
import astropy.units as u
import matplotlib.pyplot as plt
from utils import fits_plot, show_shift
ps_band = 'g'

fdir = '/home/liangrd/optical_data/EP260402a/sitian/2026-04-20_EP260402a_g_com_11.wcs.fits'

fig = fits_plot(fdir,size=100,show_ps=True,ps_filter=ps_band)
# Out:
# ---------------------------------------------------------------------------
# NoOverlapError                            Traceback (most recent call last)
# Cell In[3], line 11
#       7 ps_band = 'g'
#       9 fdir = '/home/liangrd/optical_data/EP260402a/sitian/2026-04-20_EP260402a_g_com_11.wcs.fits'
# ---> 11 fig = fits_plot(fdir,size=100,show_ps=True,ps_filter=ps_band)
#
# File ~/Follow_up/code/utils.py:625, in fits_plot(fdir, radius, source_dir, size, contrast, show_ps, ps_filter, ra, dec, **imshow_kwargs)
#     621     coord = SkyCoord(ra=float(row.iloc[0]['RA'])*u.deg,
#     622                      dec=float(row.iloc[0]['Dec'])*u.deg)
#     624 # ---------- 3. Main cutout ----------
# --> 625 cutout = Cutout2D(data, coord, size, wcs=wcs)
#     626 zscale = ZScaleInterval(contrast=contrast)
#     627 vmin, vmax = zscale.get_limits(cutout.data)
#
# File ~/epenv/lib/python3.12/site-packages/astropy/nddata/utils.py:651, in Cutout2D.__init__(self, data, position, size, wcs, mode, fill_value, copy, limit_rounding_method)
#     647 # reverse position because extract_array and overlap_slices
#     648 # use (y, x), but keep the input position
#     649 pos_yx = position[::-1]
# --> 651 cutout_data, input_position_cutout = extract_array(
#     652     data,
#     653     tuple(shape),
#     654     pos_yx,
#     655     mode=mode,
#     656     fill_value=fill_value,
#     657     return_position=True,
#     658     limit_rounding_method=limit_rounding_method,
#     659 )
#     660 if copy:
#     661     cutout_data = np.copy(cutout_data)
#
# File ~/epenv/lib/python3.12/site-packages/astropy/nddata/utils.py:262, in extract_array(array_large, shape, position, mode, fill_value, return_position, limit_rounding_method)
#     259 if mode not in ["partial", "trim", "strict"]:
#     260     raise ValueError("Valid modes are 'partial', 'trim', and 'strict'.")
# --> 262 large_slices, small_slices = overlap_slices(
#     263     array_large.shape,
#     264     shape,
#     265     position,
#     266     mode=mode,
#     267     limit_rounding_method=limit_rounding_method,
#     268 )
#     269 extracted_array = array_large[large_slices]
#     270 if return_position:
#
# File ~/epenv/lib/python3.12/site-packages/astropy/nddata/utils.py:142, in overlap_slices(large_array_shape, small_array_shape, position, mode, limit_rounding_method)
#     140 for e_min, large_shape in zip(indices_min, large_array_shape):
#     141     if e_min >= large_shape:
# --> 142         raise NoOverlapError("Arrays do not overlap.")
#     144 if mode == "strict":
#     145     for e_min in indices_min:
#
# NoOverlapError: Arrays do not overlap.

# %%
show_shift(root='/home/liangrd/Follow_up/optical_data',save_dir='/home/liangrd/Follow_up/results')
# Out:
# [ERROR] /home/liangrd/Follow_up/optical_data/EP251229a/sitian/2025-12-30_EP251229a_g_com_10.wcs.fits: buffer is too
# small for requested array
# [ERROR] /home/liangrd/Follow_up/optical_data/EP251229a/sitian/2025-12-31_EP251229a_g_com_10.wcs.fits: buffer is too
# small for requested array

# %%
# hdu = fits.open(fdir)
# header = hdu[0].header
# header
# header['OBJECT'] = 'EP J0619.5+0602'

# hdu.writeto(fdir.replace('EP251229a','EP260101a'), overwrite=True)

# %%
import time
import pandas as pd

t = pd.Timestamp('2026-01-25T21:03:16.395375+00:00')
t.strftime("%Y-%m-%dT%H:%M:%S.%f")
# Out:
# '2026-01-25T21:03:16.395375'
